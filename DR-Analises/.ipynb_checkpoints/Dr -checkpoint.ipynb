# %%
with open("2019/DR-2019-0.1.json", "r") as f:
    data = json.load(f)
    dict_temp = {}
    lista = []
    counter = 0
    for key, value in data.items():
        if(len(value)>1):
            if(counter == 1):
                for i in range(len(value)):
                    lista.append(value[i])
                counter = 2
            elif(counter == 0):
                counter = 1
                for i in range(len(value)):
                    dict_temp[(value[i][0], value[i][1])] = 0
    i = 0
    for key, value in dict_temp.items():
        dict_temp[key] = lista[i][0]
        i+=1
print(dict_temp)
# Out:
# {('Atlanta Hawks', 'Boston Celtics'): 0.0, ('Atlanta Hawks', 'Brooklyn Nets'): 0.0, ('Atlanta Hawks', 'Charlotte Hornets'): 0.0, ('Atlanta Hawks', 'Chicago Bulls'): 0.0, ('Atlanta Hawks', 'Cleveland Cavaliers'): 0.0, ('Atlanta Hawks', 'Dallas Mavericks'): 0.0, ('Atlanta Hawks', 'Denver Nuggets'): 0.0, ('Atlanta Hawks', 'Detroit Pistons'): 0.0, ('Atlanta Hawks', 'Golden State Warriors'): 0.0, ('Atlanta Hawks', 'Houston Rockets'): 0.0, ('Atlanta Hawks', 'Indiana Pacers'): 0.0, ('Atlanta Hawks', 'LA Clippers'): 0.0, ('Atlanta Hawks', 'Los Angeles Lakers'): 0.0, ('Atlanta Hawks', 'Memphis Grizzlies'): 0.0, ('Atlanta Hawks', 'Miami Heat'): 0.0, ('Atlanta Hawks', 'Milwaukee Bucks'): 0.0, ('Atlanta Hawks', 'Minnesota Timberwolves'): 0.0, ('Atlanta Hawks', 'New Orleans Pelicans'): 0.0, ('Atlanta Hawks', 'New York Knicks'): 0.0, ('Atlanta Hawks', 'Oklahoma City Thunder'): 0.0, ('Atlanta Hawks', 'Orlando Magic'): 0.0, ('Atlanta Hawks', 'Philadelphia 76ers'): 0.0, ('Atlanta Hawks', 'Phoenix Sun
# ...

# %%
## Fazer a media das rivalidades ocultas para 0,1 dr em 2019
dict_temp.items()
## Pegar todos os valores da tupla diferentes de 0,5 e 1. Somar tudo e dividir pelo tamanho
# Out:
# dict_items([(('Atlanta Hawks', 'Boston Celtics'), 0.0), (('Atlanta Hawks', 'Brooklyn Nets'), 0.0), (('Atlanta Hawks', 'Charlotte Hornets'), 0.0), (('Atlanta Hawks', 'Chicago Bulls'), 0.0), (('Atlanta Hawks', 'Cleveland Cavaliers'), 0.0), (('Atlanta Hawks', 'Dallas Mavericks'), 0.0), (('Atlanta Hawks', 'Denver Nuggets'), 0.0), (('Atlanta Hawks', 'Detroit Pistons'), 0.0), (('Atlanta Hawks', 'Golden State Warriors'), 0.0), (('Atlanta Hawks', 'Houston Rockets'), 0.0), (('Atlanta Hawks', 'Indiana Pacers'), 0.0), (('Atlanta Hawks', 'LA Clippers'), 0.0), (('Atlanta Hawks', 'Los Angeles Lakers'), 0.0), (('Atlanta Hawks', 'Memphis Grizzlies'), 0.0), (('Atlanta Hawks', 'Miami Heat'), 0.0), (('Atlanta Hawks', 'Milwaukee Bucks'), 0.0), (('Atlanta Hawks', 'Minnesota Timberwolves'), 0.0), (('Atlanta Hawks', 'New Orleans Pelicans'), 0.0), (('Atlanta Hawks', 'New York Knicks'), 0.0), (('Atlanta Hawks', 'Oklahoma City Thunder'), 0.0), (('Atlanta Hawks', 'Orlando Magic'), 0.0), (('Atlanta Hawks', 'Phi
# ...

# %%
for k in dict_temp.items():
   print (k[1])
   float soma = 0
   if(k[1] == 0.5):
        break
   elif(k[1] == 1):
        break
   else:
        soma += k[1]
        
print(soma)
# Out:
# 0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a9302e0ae1f2> in <module>
#       6         break
#       7    else:
# ----> 8         soma += k[1]
#       9
#      10 print(soma)
#
# NameError: name 'soma' is not defined
