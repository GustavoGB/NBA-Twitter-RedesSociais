# %%
import pymysql
import json
from functools import partial
import csv

def run_db_query(connection, query, args=None):
    with connection.cursor() as cursor:
        print('Executando query:')
        cursor.execute(query, args)
        for result in cursor:
            print(result)
            
def return_db_results(connection, query, args=None):#Gambiarra para pegar o id
    with connection.cursor() as cursor:
        cursor.execute(query, args)
        for result in cursor:
            return result #retorna logo o primeiro
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='vlm1998',
    database='redes')

db = partial(run_db_query, connection)

# %%
#db('DROP DATABASE IF EXISTS redes')

# %%
db('SHOW TABLES')
db('DESCRIBE transferencia')
# Out:
# Executando query:
# ('jogador',)
# ('jogador_tag',)
# ('rivalidade',)
# ('times',)
# ('transferencia',)
# ('waived',)
# Executando query:
# ('id_transferencia', 'int(11)', 'NO', 'PRI', None, 'auto_increment')
# ('id_jogador', 'int(11)', 'NO', 'PRI', None, '')
# ('id_time', 'int(11)', 'NO', 'PRI', None, '')
# ('ano', 'int(11)', 'NO', 'PRI', None, '')

# %%
with open("signed.json", 'r') as f: #LISTA DAS TRANSFERENCIAS COLETADAS NO SCRAPPING
    signed = json.load(f)
    
with open("waived.json", 'r') as f: #LISTA DAS TRANSFERENCIAS COLETADAS NO SCRAPPING
    waived = json.load(f)
    
with open("all_players.json", 'r') as f: #LISTA DOS JOGADORES COLETADOS POR SCRAPPING
    all_players = json.load(f)
    
all_teams = ["Golden State Warriors", "LA Clippers","Boston Celtics", "Chicago Bulls", "Houston Rockets", "Cleveland Cavaliers", 
                "Dallas Mavericks", "Los Angeles Lakers", "Brooklyn Nets", "Memphis Grizzlies", "Washington Wizards", "Oklahoma City Thunder", 
                "Miami Heat", "Minnesota Timberwolves", "Indiana Pacers", "Denver Nuggets", "Charlotte Hornets", "Philadelphia 76ers", 
                "Portland Trail Blazers", "Boston Celtics", "Milwaukee Bucks", "New Orleans Pelicans", "Toronto Raptors", "Phoenix Suns",
                "New York Knicks", "Detroit Pistons", "Utah Jazz", "Sacramento Kings", "Atlanta Hawks", "Orlando Magic", "San Antonio Spurs"]

# %%
#PRIMERIO PASSO: COLOCAR TODOS JOGADORES E TODOS OS TIMES EM SUAS TABELAS
#SEGUNDO PASSO: PARA CADA TRANSFERENCIA, PROCURAR O ID DO JOGADOR E DO TIME E COLOCAR A TRANSFERENCIA NA TABELA DE TRANSFERENCIAS

# %%
#Colocando os jogadores no banco de dados
for player in all_players:
    try:
        query = ('INSERT INTO jogador (nome) VALUES (%s)')
        arg = player
        run_db_query(connection, query, arg)
    except Exception as e:
        print(e)
# Out:
# Executando query:
# (1062, "Duplicate entry 'Alaa Abdelnaby' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Zaid Abdul-Aziz' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Kareem Abdul-Jabbar' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Mahmoud Abdul-Rauf' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Tariq Abdul-Wahad' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Shareef Abdur-Rahim' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Tom Abernethy' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Forest Able' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'John Abramovic' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Alex Abrines' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Alex Acker' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Donald Ackerman' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Mark Acres' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Charles Acton' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Quincy Acy' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Alvan Adams' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Don Adams' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Hassan Adams' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Jaylen Adams' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Jordan Adams' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Michael Adams' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Steven Adams' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Rafael Addison' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Bam Adebayo' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Deng Adel' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Rick Adelman' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Jeff Adrien' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Arron Afflalo' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Maurice Ager' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Mark Aguirre' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Blake Ahearn' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Danny Ainge' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Alexis Ajinca' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Henry Akin' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Josh Akognon' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'DeVaughn Akoon-Purcell' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry '
for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Luke Zeller' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Tyler Zeller' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Tony Zeno' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Phil Zevenbergen' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Wang Zhi-zhi' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'George Zidek' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Derrick Zimmerman' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Stephen Zimmerman' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Paul Zipser' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Ante Zizic' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Jim Zoet' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Bill Zopf' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Ivica Zubac' for key 'nome'")
# Executando query:
# (1062, "Duplicate entry 'Matt Zunic' for key 'nome'")

# %%
#Colocando os times no banco de dados
for team in all_teams:
    try:
        query = ('INSERT INTO times (nome) VALUES (%s)')
        arg = team
        run_db_query(connection, query, arg)
    except Exception as e:
        print(e)
# Out:
# Executando query:
# (1062, "Duplicate entry 'Golden State Warriors' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'LA Clippers' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Boston Celtics' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Chicago Bulls' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Houston Rockets' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Cleveland Cavaliers' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Dallas Mavericks' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Los Angeles Lakers' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Brooklyn Nets' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Memphis Grizzlies' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Washington Wizards' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Oklahoma City Thunder' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Miami Heat' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Minnesota Timberwolves' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Indiana Pacers' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Denver Nuggets' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Charlotte Hornets' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Philadelphia 76ers' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Portland Trail Blazers' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Boston Celtics' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Milwaukee Bucks' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'New Orleans Pelicans' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Toronto Raptors' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Phoenix Suns' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'New York Knicks' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Detroit Pistons' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Utah Jazz' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Sacramento Kings' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Atlanta Hawks' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'Orlando Magic' for key 'constr_1'")
# Executando query:
# (1062, "Duplicate entry 'San Antonio Spurs' for key 'constr_1'")

# %%
#Inserindo as transferencias no banco de dados
for key in signed:
    query = ('SELECT id_jogador FROM jogador WHERE nome = %s')
    arg = [key]
    id_jogador = return_db_results(connection, query, arg)[0] #Mais uma gambiarra

    query = ('SELECT id_time FROM times WHERE nome = %s')
    arg = signed[key][0]
    id_time = return_db_results(connection, query, arg)[0] 
        
    query = ('INSERT INTO transferencia (id_jogador, id_time, ano) VALUES (%s,%s,%s)')
    arg = [id_jogador, id_time, signed[key][1]]
    run_db_query(connection, query, arg)
# Out:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:

# %%
#Inserindo as transferencias no banco de dados
for key in waived:
    query = ('SELECT id_jogador FROM jogador WHERE nome = %s')
    arg = [key]
    id_jogador = return_db_results(connection, query, arg)[0] #Mais uma gambiarra

    query = ('SELECT id_time FROM times WHERE nome = %s')
    arg = waived[key][0]
    id_time = return_db_results(connection, query, arg)[0] 
        
    query = ('INSERT INTO waived (id_jogador, id_time, ano) VALUES (%s,%s,%s)')
    arg = [id_jogador, id_time, waived[key][1]]
    run_db_query(connection, query, arg)
# Out:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:

# %%
dict_tags = {}
with open('tags.txt', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        fim = row["Player"].find("\\")
        row["Player"] = row["Player"][:fim]
        dict_tags[row["Player"]] = row["Twitter"]
        line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are Rk, Player, Twitter
# Processed 1160 lines.

# %%
#Inserindo as transferencias no banco de dados
for key in dict_tags:
    try:
        query = ('SELECT id_jogador FROM jogador WHERE nome = %s')
        arg = [key]
        id_jogador = return_db_results(connection, query, arg)[0] #Mais uma gambiarra

        query = ('INSERT INTO jogador_tag (id_jogador, tag) VALUES (%s,%s)')
        arg = [id_jogador, dict_tags[key]]
        run_db_query(connection, query, arg)
    except:
        continue
# Out:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:
# Executando query:

# %%
#Inserindo as rivalidades
dict_intra_leste = {"Boston Celtics" : ["Brooklyn Nets", "New York Knicks",  "Detroit Pistons", "Orlando Magic", "Chicago Bulls", "Atlanta Hawks", "Miami Heat" ],
                    "New York Knicks" : ["Philadelphia 76ers"], 
                    "Chicago Bulls" : ["Milwaukee Bucks", "Indiana Pacers", "Miami Heat", "New York Knicks" ],
                    "Indiana Pacers" : ["Detroit Pistons", "New York Knicks"],
                    "Miami Heat" : ["Orlando Magic", "New York Knicks"],
                    "Cleveland Cavaliers" : ["Orlando Magic","Washington Wizards", "Miami Heat"]}

dict_intra_oeste = {"Los Angeles Lakers" : ["LA Clippers","Phoenix Suns", "Sacramento Kings"],
                    "Houston Rockets" : ["San Antonio Spurs","Utah Jazz"],
                   "San Antonio Spurs" : ["Dallas Mavericks","Phoenix Suns" ],
                    "Dallas Mavericks" : ["Phoenix Suns"], 
                    "Phoenix Suns" : ["Portland Trail Blazers"]}

dict_biggest = {"Boston Celtics" : ["Los Angeles Lakers", "Philadelphia 76ers"],
                "Los Angeles Lakers" : ["Philadelphia 76ers", "Detroit Pistons"],
                "Milwaukee Bucks" : ["Minnesota Timberwolves"], 
                "Chicago Bulls" : ["Utah Jazz", "Detroit Pistons"],
                "Cleveland Cavaliers" : ["Golden State Warriors"],
                "San Antonio Spurs" : ["Los Angeles Lakers"]}
for key in dict_biggest: #O peso do dict_biggest é 1 e os outros 0.5
    try:
        lista_id_time2 = [] #zera a lista para cada key
        query = ('SELECT id_time FROM times WHERE nome = %s')
        arg = [key]
        id_time1 = return_db_results(connection, query, arg)[0] #Mais uma gambiarra
        for time in dict_biggest[key]:
            query = ('SELECT id_time FROM times WHERE nome = %s')
            arg = time
            lista_id_time2.append(return_db_results(connection, query, arg)[0]) #Mais uma gambiarra
        for id_time2 in lista_id_time2:
            query = ('INSERT INTO rivalidade (id_time1, id_time2, ano, peso) VALUES (%s, %s, 2019, 1.0)') #Por enquanto apenas 2019
            arg = [id_time1, id_time2]
            run_db_query(connection, query, arg)
    except Exception as e:
        print(e)
        
for key in dict_intra_leste: #O peso do dict_biggest é 1 e os outros 0.5
    try:
        lista_id_time2 = [] #zera a lista para cada key
        query = ('SELECT id_time FROM times WHERE nome = %s')
        arg = [key]
        id_time1 = return_db_results(connection, query, arg)[0] #Mais uma gambiarra
        for time in dict_intra_leste[key]:
            query = ('SELECT id_time FROM times WHERE nome = %s')
            arg = time
            lista_id_time2.append(return_db_results(connection, query, arg)[0]) #Mais uma gambiarra
        for id_time2 in lista_id_time2:
            query = ('INSERT INTO rivalidade (id_time1, id_time2, ano, peso) VALUES (%s, %s, 2019, 0.5)') #Por enquanto apenas 2019
            arg = [id_time1, id_time2]
            run_db_query(connection, query, arg)
    except Exception as e:
        print(e)
        
for key in dict_intra_oeste: #O peso do dict_biggest é 1 e os outros 0.5
    try:
        lista_id_time2 = [] #zera a lista para cada key
        query = ('SELECT id_time FROM times WHERE nome = %s')
        arg = [key]
        id_time1 = return_db_results(connection, query, arg)[0] #Mais uma gambiarra
        for time in dict_intra_oeste[key]:
            query = ('SELECT id_time FROM times WHERE nome = %s')
            arg = time
            lista_id_time2.append(return_db_results(connection, query, arg)[0]) #Mais uma gambiarra
        for id_time2 in lista_id_time2:
            query = ('INSERT INTO rivalidade (id_time1, id_time2, ano, peso) VALUES (%s, %s, 2019, 0.5)') #Por enquanto apenas 2019
            arg = [id_time1, id_time2]
            run_db_query(connection, query, arg)
    except Exception as e:
        print(key)
        print(e)
# Out:
# Executando query:
# (1062, "Duplicate entry '3-8' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '8-18' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '21-14' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '4-27' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '6-1' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '31-8' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '3-9' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '25-18' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '4-21' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '15-26' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '13-30' for key 'PRIMARY'")
# Executando query:
# (1062, "Duplicate entry '6-30' for key 'PRIMARY'")
# Executando query:
# Los Angeles Lakers
# (1062, "Duplicate entry '8-2' for key 'PRIMARY'")
# Executando query:
# Houston Rockets
# (1062, "Duplicate entry '5-31' for key 'PRIMARY'")
# Executando query:
# San Antonio Spurs
# (1062, "Duplicate entry '31-7' for key 'PRIMARY'")
# Executando query:
# Dallas Mavericks
# (1062, "Duplicate entry '7-24' for key 'PRIMARY'")
# Executando query:
# Phoenix Suns
# (1062, "Duplicate entry '24-19' for key 'PRIMARY'")

# %%
#db('SELECT * FROM jogador')
#db('SELECT * FROM times')
#db('SELECT * FROM transferencia')
#db('SELECT * FROM jogador_tag')
#db('SELECT * FROM waived')

#db('SELECT id_time from times WHERE nome = "Boston Celtics" ')
#db('SELECT COUNT(*) from rivalidade WHERE id_time1 = "" ')
db('SELECT * FROM rivalidade')
# Out:
# Executando query:
# (3, 4, 2019, 0.5)
# (3, 8, 2019, 1.0)
# (3, 9, 2019, 0.5)
# (3, 13, 2019, 0.5)
# (3, 18, 2019, 1.0)
# (3, 25, 2019, 0.5)
# (3, 26, 2019, 0.5)
# (3, 29, 2019, 0.5)
# (3, 30, 2019, 0.5)
# (4, 13, 2019, 0.5)
# (4, 15, 2019, 0.5)
# (4, 21, 2019, 0.5)
# (4, 25, 2019, 0.5)
# (4, 26, 2019, 1.0)
# (4, 27, 2019, 1.0)
# (5, 27, 2019, 0.5)
# (5, 31, 2019, 0.5)
# (6, 1, 2019, 1.0)
# (6, 11, 2019, 0.5)
# (6, 13, 2019, 0.5)
# (6, 30, 2019, 0.5)
# (7, 24, 2019, 0.5)
# (8, 2, 2019, 0.5)
# (8, 18, 2019, 1.0)
# (8, 24, 2019, 0.5)
# (8, 26, 2019, 1.0)
# (8, 28, 2019, 0.5)
# (13, 25, 2019, 0.5)
# (13, 30, 2019, 0.5)
# (15, 25, 2019, 0.5)
# (15, 26, 2019, 0.5)
# (21, 14, 2019, 1.0)
# (24, 19, 2019, 0.5)
# (25, 18, 2019, 0.5)
# (31, 7, 2019, 0.5)
# (31, 8, 2019, 1.0)
# (31, 24, 2019, 0.5)

# %%
connection.commit()

# %%
connection.close()
